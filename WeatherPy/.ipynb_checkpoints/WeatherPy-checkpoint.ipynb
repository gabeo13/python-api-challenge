# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
root = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'metric'
search = f'{root}appid={weather_api_key}&units={units}&q='

lat=[]
lng=[]
mxtemp=[]
humd=[]
cloud=[]
wndsp=[]
cntry=[]
date=[]
fndcity=[]

grp = 1

for idx, city in enumerate(cities):
    
    try:
        print(f'Processing Record {idx} of Set {grp} | {city}')
        
        response = requests.get(search+city).json()
        lng.append(response['coord']['lon'])
        lat.append(response['coord']['lat'])    
        mxtemp.append(response['main']['temp_max'])  
        humd.append(response['main']['humidity'])  
        cloud.append(response['clouds']['all'])  
        wndsp.append(response['wind']['speed'])  
        cntry.append(response['sys']['country'])  
        date.append(response['dt'])
        fndcity.append(response['name'])
        
    except (KeyError, IndexError):
        print('City not found. Skipping...')
        grp=grp+1
# Out:
# Processing Record 0 of Set 1 | mocuba
# Processing Record 1 of Set 1 | volosovo
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | turukhansk
# Processing Record 4 of Set 1 | qaanaaq
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | druskininkai
# Processing Record 7 of Set 1 | mount isa
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | san joaquin
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | turochak
# Processing Record 13 of Set 1 | gweta
# Processing Record 14 of Set 1 | longyearbyen
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | nesna
# Processing Record 17 of Set 1 | tual
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | puerto leguizamo
# Processing Record 21 of Set 2 | placido de castro
# Processing Record 22 of Set 2 | bethel
# Processing Record 23 of Set 2 | lemesos
# City not found. Skipping...
# Processing Record 24 of Set 3 | raozan
# City not found. Skipping...
# Processing Record 25 of Set 4 | hobart
# Processing Record 26 of Set 4 | coihaique
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 30 of Set 6 | mount gambier
# Processing Record 31 of Set 6 | yanliang
# Processing Record 32 of Set 6 | kozhva
# Processing Record 33 of Set 6 | eau claire
# Processing Record 34 of Set 6 | port blair
# Processing Record 35 of Set 6 | naze
# Processing Record 36 of Set 6 | bredasdorp
# Processing Record 37 of Set 6 | cape town
# Processing Record 38 of Set 6 | avarua
# Processing Record 39 of Set 6 | nantucket
# Processing Record 40 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 41 of Set 7 | mataura
# Processing Record 42 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 8 | rikitea
# Processing Record 44 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 45 of Set 9 | kidal
# Processing Record 46 of Set 9 | saint george
# Processing Record 47 of Set 9 | lata
# Processing Record 48 of Set 9 | mahebourg
# Processing Record 49 of Set 9 | havoysund
# Processing Record 50 of Set 9 | hirara
# Processing Record 51 of Set 9 | east london
# Processing Record 52 of Set 9 | lompoc
# Processing Record 53 of Set 9 | lavrentiya
# Processing Record 54 of Set 9 | samarai
# Processing Record 55 of Set 9 | tchollire
# Processing Record 56 of Set 9 | tuban
# Processing Record 57 of Set 9 | kapaa
# Processing Record 58 of Set 9 | lerwick
# Processing Record 59 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 60 of Set 10 | castro
# Processing Record 61 of Set 10 | baykit
# Processing Record 62 of Set 10 | provideniya
# Processing Record 63 of Set 10 | chokurdakh
# Processing Record 64 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 65 of Set 11 | villarrica
# Processing Record 66 of Set 11 | nemuro
# Processing Record 67 of Set 11 | ray
# Processing Record 68 of Set 11 | sungairaya
# Processing Record 69 of Set 11 | kodiak
# Processing Record 70 of Set 11 | ushuaia
# Processing Record 71 of Set 11 | san-pedro
# Processing Record 72 of Set 11 | punta arenas
# Processing Record 73 of Set 11 | port alfred
# Processing Record 74 of Set 11 | aksu
# Processing Record 75 of Set 11 | taolanaro
# City not found. Skipping...
# Processing Record 76 of Set 12 | uige
# Processing Record 77 of Set 12 | chuy
# Processing Record 78 of Set 12 | ukiah
# Processing Record 79 of Set 12 | mogocha
# Processing Record 80 of Set 12 | saint-philippe
# Processing Record 81 of Set 12 | tuktoyaktuk
# Processing Record 82 of Set 12 | atherton
# Processing Record 83 of Set 12 | cabo san lucas
# Processing Record 84 of Set 12 | albany
# Processing Record 85 of Set 12 | kudahuvadhoo
# Processing Record 86 of Set 12 | ribeira grande
# Processing Record 87 of Set 12 | new norfolk
# Processing Record 88 of Set 12 | tuatapere
# Processing Record 89 of Set 12 | armacao dos buzios
# City not found. Skipping...
# Processing Record
# Processing Record 382 of Set 40 | tanout
# Processing Record 383 of Set 40 | tura
# Processing Record 384 of Set 40 | payo
# Processing Record 385 of Set 40 | kahului
# Processing Record 386 of Set 40 | noumea
# Processing Record 387 of Set 40 | ambulu
# Processing Record 388 of Set 40 | tekeli
# Processing Record 389 of Set 40 | port-gentil
# Processing Record 390 of Set 40 | deori khas
# Processing Record 391 of Set 40 | palabuhanratu
# City not found. Skipping...
# Processing Record 392 of Set 41 | harper
# Processing Record 393 of Set 41 | whitehorse
# Processing Record 394 of Set 41 | marquette
# Processing Record 395 of Set 41 | bahia honda
# Processing Record 396 of Set 41 | banda aceh
# Processing Record 397 of Set 41 | vagur
# Processing Record 398 of Set 41 | esso
# Processing Record 399 of Set 41 | alihe
# Processing Record 400 of Set 41 | chagda
# City not found. Skipping...
# Processing Record 401 of Set 42 | ellisras
# Processing Record 402 of Set 42 | qaqortoq
# Processing Record 403 of Set 42 | auray
# Processing Record 404 of Set 42 | surovatikha
# Processing Record 405 of Set 42 | awjilah
# Processing Record 406 of Set 42 | byron bay
# Processing Record 407 of Set 42 | pasinler
# Processing Record 408 of Set 42 | iskateley
# Processing Record 409 of Set 42 | huarmey
# Processing Record 410 of Set 42 | half moon bay
# Processing Record 411 of Set 42 | oga
# Processing Record 412 of Set 42 | komsomolskiy
# Processing Record 413 of Set 42 | kasangulu
# Processing Record 414 of Set 42 | noyabrsk
# Processing Record 415 of Set 42 | manaus
# Processing Record 416 of Set 42 | yithion
# City not found. Skipping...
# Processing Record 417 of Set 43 | golden gate
# Processing Record 418 of Set 43 | gaziantep
# Processing Record 419 of Set 43 | mys shmidta
# City not found. Skipping...
# Processing Record 420 of Set 44 | alta
# Processing Record 421 of Set 44 | alice springs
# Processing Record 422 of Set 44 | ilulissat
# Processing Record 423 of Set 44 | bridgetown
# Processing Record 424 of Set 44 | morros
# Processing Record 425 of Set 44 | semey
# Processing Record 426 of Set 44 | ranfurly
# Processing Record 427 of Set 44 | lima
# Processing Record 428 of Set 44 | samusu
# City not found. Skipping...
# Processing Record 429 of Set 45 | chapais
# Processing Record 430 of Set 45 | mocambique
# City not found. Skipping...
# Processing Record 431 of Set 46 | eydhafushi
# Processing Record 432 of Set 46 | ravar
# Processing Record 433 of Set 46 | benguela
# Processing Record 434 of Set 46 | xining
# Processing Record 435 of Set 46 | tevriz
# Processing Record 436 of Set 46 | krasnyy chikoy
# Processing Record 437 of Set 46 | fort nelson
# Processing Record 438 of Set 46 | guerrero negro
# Processing Record 439 of Set 46 | villefontaine
# Processing Record 440 of Set 46 | murgab
# Processing Record 441 of Set 46 | gaoual
# Processing Record 442 of Set 46 | luderitz
# Processing Record 443 of Set 46 | rab
# City not found. Skipping...
# Processing Record 444 of Set 47 | labuan
# Processing Record 445 of Set 47 | vredendal
# Processing Record 446 of Set 47 | boguchany
# Processing Record 447 of Set 47 | geraldton
# Processing Record 448 of Set 47 | shelburne
# Processing Record 449 of Set 47 | neiafu
# Processing Record 450 of Set 47 | kalaleh
# Processing Record 451 of Set 47 | maceio
# Processing Record 452 of Set 47 | canico
# Processing Record 453 of Set 47 | san quintin
# Processing Record 454 of Set 47 | biscarrosse
# Processing Record 455 of Set 47 | kabo
# Processing Record 456 of Set 47 | anju
# Processing Record 457 of Set 47 | saint-georges
# Processing Record 458 of Set 47 | coquimbo
# Processing Record 459 of Set 47 | sarahan
# Processing Record 460 of Set 47 | los llanos de aridane
# Processing Record 461 of Set 47 | port macquarie
# Processing Record 462 of Set 47 | koslan
# Processing Record 463 of Set 47 | ahipara
# Processing Record 464 of Set 47 | ostrovnoy
# Processing Record 465 of Set 47 | waverly
# Processing Record 466 of Set 47 | peace river
# Processing Record 467 of Set 47 | morro bay
# Processing Record 468 of Set 47 | sola
# Processing Record 469 of Set 47 | terney
# Processing Record 470 of Set 47 | rio grande
# Processing Record 471 of Set 47 | broken hill
# Processing Record 472 of Set 47 | villa carlos paz
# Processing Record 473 of Set 47 | sinaloa
# Processing Record 474 of Set 47 | maniitsoq
# Processing Record 475 of Set 47 | luganville
# Processing Record 476 of Set 47 | batemans bay
# Processing Record 477 of Set 47 | la brea
# Processing Record 478 of Set 47 | vigrestad
# Processing Record 479 of Set 47 | madang
# Processing Record 480 of Set 47 | gamba
# Processing Record 481 of Set 47 | balotra
# Processing Record 482 of Set 47 | yichang
# Processing Record 483 of Set 47 | bedele
# Processing Record 484 of Set 47 | jiayuguan
# Processing Record 485 of Set 47 | chaman
# Processing Record 486 of Set 47 | shwebo
# Processing Record 487 of Set 47 | bonavista
# Processing Record 488 of Set 47 | macaboboni
# City not found. Skipping...
# Processing Record 489 of Set 48 | altzayanca
# Processing Record 490 of Set 48 | cayenne
# Processing Record 491 of Set 48 | uvarovo
# Processing Record 492 of Set 48 | vila velha
# Processing Record 493 of Set 48 | beberibe
# Processing Record 494 of Set 48 | kendari
# Processing Record 495 of Set 48 | constitucion
# Processing Record 496 of Set 48 | taywarah
# Processing Record 497 of Set 48 | minyar
# Processing Record 498 of Set 48 | revelstoke
# Processing Record 499 of Set 48 | kota kinabalu
# Processing Record 500 of Set 48 | ulundurpettai
# City not found. Skipping...
# Processing Record 501 of Set 49 | raahe
# Processing Record 502 of Set 49 | pongol
# Processing Record 503 of Set 49 | tumannyy
# City not found. Skipping...
# Processing Record 504 of Set 50 | lazaro cardenas
# Processing Record 505 of Set 50 | khor
# Processing Record 506 of Set 50 | olafsvik
# Processing Record 507 of Set 50 | kilimatinde
# Processing Record 508 of Set 50 | tombouctou
# Processing Record 509 of Set 50 | kushmurun
# Processing Record 510 of Set 50 | male
# Processing Record 511 of Set 50 | xapuri
# Processing Record 512 of Set 50 | solnechnyy
# Processing Record 513 of Set 50 | vila franca do campo
# Processing Record 514 of Set 50 | sokoto
# Processing Record 515 of Set 50 | brenham
# Processing Record 516 of Set 50 | tilichiki
# Processing Record 517 of Set 50 | nanortalik
# Processing Record 518 of Set 50 | mongoumba
# Processing Record 519 of Set 50 | kirkland lake
# Processing Record 520 of Set 50 | wukari
# Processing Record 521 of Set 50 | kushiro
# Processing Record 522 of Set 50 | kokopo
# Processing Record 523 of Set 50 | trelew
# Processing Record 524 of Set 50 | choix
# Processing Record 525 of Set 50 | husavik
# Processing Record 526 of Set 50 | xichang
# Processing Record 527 of Set 50 | sistranda


# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict={
    'City':fndcity,'Lat':lat, 'Lng':lng,
    'Max Temp':mxtemp,'Humidity':humd,'Cloudiness':cloud,
    'Wind Speed':wndsp, 'Country':cntry, 'Date':date
}

weather_df = pd.DataFrame(weather_dict)
weather_df.to_csv(output_data_file)
weather_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Mocuba -16.8392   36.9856     24.43        89         100        3.10
# 1    Volosovo  59.4333   29.4833      1.00        93          75        3.00
# 2   Busselton -33.6500  115.3333     28.89        51           1        3.13
# 3  Turukhansk  65.8167   87.9833    -37.51        74          65        2.82
# 4     Qaanaaq  77.4840  -69.3632     -9.47        81          21        2.95
#
#   Country        Date
# 0      MZ  1611380910
# 1      RU  1611380910
# 2      AU  1611380911
# 3      RU  1611380911
# 4      GL  1611380911

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  548.000000  548.000000  548.000000  548.000000  548.000000  548.000000
# mean    21.732747   18.711196    8.610675   73.693431   57.023723    3.339854
# std     32.919708   90.377656   18.999606   19.381030   38.305104    2.412704
# min    -54.800000 -179.166700  -43.870000    7.000000    0.000000    0.040000
# 25%     -4.082425  -59.718775   -4.095000   64.000000   20.000000    1.540000
# 50%     26.633550   23.700000   14.960000   78.000000   75.000000    2.760000
# 75%     49.798175   96.188875   24.000000   88.000000   91.000000    4.595000
# max     78.218600  178.416700   39.000000  100.000000  100.000000   14.250000
#
#                Date
# count  5.480000e+02
# mean   1.611381e+09
# std    6.747909e+01
# min    1.611380e+09
# 25%    1.611381e+09
# 50%    1.611381e+09
# 75%    1.611381e+09
# max    1.611381e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hum_count = weather_df[weather_df['Humidity']>100].count()
hum_count
# Out:
# City          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# Country       0
# Date          0
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.
hum_index = weather_df[weather_df['Humidity']>100].index
hum_index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df.drop(hum_index, inplace=False)

# %%
clean_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  548.000000  548.000000  548.000000  548.000000  548.000000  548.000000
# mean    21.732747   18.711196    8.610675   73.693431   57.023723    3.339854
# std     32.919708   90.377656   18.999606   19.381030   38.305104    2.412704
# min    -54.800000 -179.166700  -43.870000    7.000000    0.000000    0.040000
# 25%     -4.082425  -59.718775   -4.095000   64.000000   20.000000    1.540000
# 50%     26.633550   23.700000   14.960000   78.000000   75.000000    2.760000
# 75%     49.798175   96.188875   24.000000   88.000000   91.000000    4.595000
# max     78.218600  178.416700   39.000000  100.000000  100.000000   14.250000
#
#                Date
# count  5.480000e+02
# mean   1.611381e+09
# std    6.747909e+01
# min    1.611380e+09
# 25%    1.611381e+09
# 50%    1.611381e+09
# 75%    1.611381e+09
# max    1.611381e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
clean_city_data.plot.scatter('Lat',"Max Temp", c='Max Temp',title='Max Temp vs Latitude',
                             colormap='coolwarm',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Max Temp (C)',fontsize=12)
plt.savefig('output_data/lat_temp.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
clean_city_data.plot.scatter('Lat',"Humidity", c='Humidity',title='Humidity vs Latitude',
                             colormap='BrBG',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Humidity (%)',fontsize=12)
plt.savefig('output_data/lat_humd.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clean_city_data.plot.scatter('Lat',"Cloudiness", c='Cloudiness',title='Cloudiness vs Latitude',
                             colormap='bone',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Cloudiness (%)',fontsize=12)
plt.savefig('output_data/lat_cloud.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
clean_city_data.plot.scatter('Lat',"Wind Speed", c='Wind Speed',title='Wind Speed vs Latitude',
                             colormap='Reds',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Wind Speed  (m/s)',fontsize=12)
plt.savefig('output_data/lat_wind.png')

# %% [markdown]
# ## Linear Regression

# %%
north_df = clean_city_data[clean_city_data['Lat']>0]
south_df = clean_city_data[clean_city_data['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
north_df.plot.scatter('Lat',"Max Temp", c='Max Temp',title='Northern Hem-Max Temp vs Latitude',
                             colormap='coolwarm',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Max Temp (C)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'], north_df['Max Temp'])

# Calculate target values for regression line 
regress_values = north_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(north_df['Lat'],regress_values,'-r')

plt.text(0,-30,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

plt.savefig('output_data/reg_norlat_temp.png')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
south_df.plot.scatter('Lat',"Max Temp", c='Max Temp',title='Southern Hem-Max Temp vs Latitude',
                             colormap='coolwarm',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Max Temp (C)',fontsize=12)
# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'], south_df['Max Temp'])

# Calculate target values for regression line 
regress_values = south_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(south_df['Lat'],regress_values,"r-")

plt.text(-30,10,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

plt.savefig('output_data/reg_sudlat_temp.png')

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
north_df.plot.scatter('Lat',"Humidity", c='Humidity',title='Northern Hem-Humidity vs Latitude',
                             colormap='BrBG',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Humidity (%)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'], north_df['Humidity'])

# Calculate target values for regression line 
regress_values = north_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(north_df['Lat'],regress_values,'-r')

plt.text(40,30,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

plt.savefig('output_data/reg_norlat_humd.png')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
south_df.plot.scatter('Lat',"Humidity", c='Humidity',title='Southern Hem-Humidity vs Latitude',
                             colormap='BrBG',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Humidity (%)',fontsize=12)
# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'], south_df['Humidity'])

# Calculate target values for regression line 
regress_values = south_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(south_df['Lat'],regress_values,"r-")

plt.text(-20,20,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

plt.savefig('output_data/reg_sudlat_humd.png')

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
north_df.plot.scatter('Lat',"Cloudiness", c='Cloudiness',title='Northern Hem-Cloudiness vs Latitude',
                             colormap='bone',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Cloudiness (%)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'], north_df['Cloudiness'])

# Calculate target values for regression line 
regress_values = north_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(north_df['Lat'],regress_values,'-r')

plt.text(40,95,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

plt.savefig('output_data/reg_norlat_cloud.png')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
south_df.plot.scatter('Lat',"Cloudiness", c='Cloudiness',title='Southern Hem-Cloudiness vs Latitude',
                             colormap='bone',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Cloudiness (%)',fontsize=12)
# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'], south_df['Cloudiness'])

# Calculate target values for regression line 
regress_values = south_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(south_df['Lat'],regress_values,"r-")

plt.text(-55,95,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

plt.savefig('output_data/reg_sudlat_cloud.png')

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
north_df.plot.scatter('Lat',"Wind Speed", c='Wind Speed',title='Northern Hem-Wind Speed vs Latitude',
                             colormap='Reds',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Wind Speed (m/s)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'], north_df['Wind Speed'])

# Calculate target values for regression line 
regress_values = north_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(north_df['Lat'],regress_values,'-r')

plt.text(0,13,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

plt.savefig('output_data/reg_norlat_wind.png')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
south_df.plot.scatter('Lat',"Wind Speed", c='Wind Speed',title='Southern Hem-Wind Speed vs Latitude',
                             colormap='Reds',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Wind Speed (m/s)',fontsize=12)
# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'], south_df['Wind Speed'])

# Calculate target values for regression line 
regress_values = south_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.plot(south_df['Lat'],regress_values,"r-")

plt.text(-18,8,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

plt.savefig('output_data/reg_sudlat_wind.png')
