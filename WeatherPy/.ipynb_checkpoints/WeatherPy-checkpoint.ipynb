# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set base url and parameters
root = 'http://api.openweathermap.org/data/2.5/weather?'
units = 'imperial'
search = f'{root}appid={weather_api_key}&units={units}&q='

# Build list containers hold parsed json results from api call
lat=[]
lng=[]
mxtemp=[]
humd=[]
cloud=[]
wndsp=[]
cntry=[]
date=[]
fndcity=[]

# Prime set counter for printing iteration progress
grp = 1

# Loop through call to open weather api and append target values to list containers
for idx, city in enumerate(cities):
    
    # Error handling of missing city value, and printig iteration progress
    try:
        print(f'Processing Record {idx} of Set {grp} | {city}')
        
        response = requests.get(search+city).json()
        lng.append(response['coord']['lon'])
        lat.append(response['coord']['lat'])    
        mxtemp.append(response['main']['temp_max'])  
        humd.append(response['main']['humidity'])  
        cloud.append(response['clouds']['all'])  
        wndsp.append(response['wind']['speed'])  
        cntry.append(response['sys']['country'])  
        date.append(response['dt'])
        fndcity.append(response['name'])
    
    # Error handling continued and increment set counter
    except (KeyError, IndexError):
        print('City not found. Skipping...')
        grp=grp+1
# Out:
# Processing Record 0 of Set 1 | solnechnyy
# Processing Record 1 of Set 1 | bethel
# Processing Record 2 of Set 1 | xining
# Processing Record 3 of Set 1 | albany
# Processing Record 4 of Set 1 | krasnoselkup
# Processing Record 5 of Set 1 | lagoa
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | sabha
# Processing Record 8 of Set 1 | senmonorom
# City not found. Skipping...
# Processing Record 9 of Set 2 | chokurdakh
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 4 | rio gallegos
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | atuona
# Processing Record 15 of Set 4 | ushuaia
# Processing Record 16 of Set 4 | mataura
# Processing Record 17 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | busselton
# Processing Record 19 of Set 5 | bathsheba
# Processing Record 20 of Set 5 | punta arenas
# Processing Record 21 of Set 5 | loughrea
# Processing Record 22 of Set 5 | carballo
# Processing Record 23 of Set 5 | hobart
# Processing Record 24 of Set 5 | walvis bay
# Processing Record 25 of Set 5 | saint-philippe
# Processing Record 26 of Set 5 | kiunga
# Processing Record 27 of Set 5 | auki
# Processing Record 28 of Set 5 | darab
# Processing Record 29 of Set 5 | praia
# Processing Record 30 of Set 5 | parabel
# Processing Record 31 of Set 5 | hilo
# Processing Record 32 of Set 5 | vaini
# Processing Record 33 of Set 5 | biak
# Processing Record 34 of Set 5 | rikitea
# Processing Record 35 of Set 5 | chuy
# Processing Record 36 of Set 5 | padang
# Processing Record 37 of Set 5 | bredasdorp
# Processing Record 38 of Set 5 | kargil
# Processing Record 39 of Set 5 | kaeo
# Processing Record 40 of Set 5 | qaanaaq
# Processing Record 41 of Set 5 | luderitz
# Processing Record 42 of Set 5 | izhmorskiy
# Processing Record 43 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 44 of Set 6 | portland
# Processing Record 45 of Set 6 | hithadhoo
# Processing Record 46 of Set 6 | kodiak
# Processing Record 47 of Set 6 | tarata
# Processing Record 48 of Set 6 | puerto ayora
# Processing Record 49 of Set 6 | port alfred
# Processing Record 50 of Set 6 | sao joao da barra
# Processing Record 51 of Set 6 | yellowknife
# Processing Record 52 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 53 of Set 7 | saldanha
# Processing Record 54 of Set 7 | key west
# Processing Record 55 of Set 7 | castro
# Processing Record 56 of Set 7 | new norfolk
# Processing Record 57 of Set 7 | butaritari
# Processing Record 58 of Set 7 | priamurskiy
# Processing Record 59 of Set 7 | alice springs
# Processing Record 60 of Set 7 | hobyo
# Processing Record 61 of Set 7 | tuatapere
# Processing Record 62 of Set 7 | torbay
# Processing Record 63 of Set 7 | bluff
# Processing Record 64 of Set 7 | makakilo city
# Processing Record 65 of Set 7 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 66 of Set 8 | kalmunai
# Processing Record 67 of Set 8 | santa catarina
# Processing Record 68 of Set 8 | pangkalanbuun
# Processing Record 69 of Set 8 | kirakira
# Processing Record 70 of Set 8 | norman wells
# Processing Record 71 of Set 8 | dumai
# Processing Record 72 of Set 8 | hermanus
# Processing Record 73 of Set 8 | nokaneng
# Processing Record 74 of Set 8 | hofn
# Processing Record 75 of Set 8 | port hedland
# Processing Record 76 of Set 8 | manokwari
# Processing Record 77 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 78 of Set 9 | arraial do cabo
# Processing Record 79 of Set 9 | carnarvon
# Processing Record 80 of Set 9 | ostrovnoy
# Processing Record 81 of Set 9 | nouna
# Processing Record 82 of Set 9 | cape town
# Processing Record 83 of Set 9 | touros
# Processing Record 84 of Set 9 | karratha
# Processing Record 85 of Set 9 | tottori
# Processing Record 86 of Set 9 | dickinson
# Processing Record 87 of Set 9 | necochea
# Processing Record 88 of Set 9 | bambari
# Processing Record 89 of Set 9 | port-gentil
# Processing Record 90 of Set 9 | iqaluit
# Processing Record 91 of Set 9 | sa kaeo
# Processing Record 92 of Set 9 | hasaki
# Processing Record 93 of Set 9 | kentville
# Processing Record 94 of Set 9 | georgetown
# Processing Record 95 of Set 9 | valreas
# Processing Record 96 of Set 9 | margate
# Processing Record 97 of Set 9 | presidente medici
# Processing Record 98 of Set 9 | mount isa
# Processing Record 99 of Set 9 | mount gambier
# Processing Record 100 of Set 9 | swan hill
# Processing Record 101 of Set 9 | kendari
# Processing Record 102 of Set 9 | namatanai
# Processing Record 103 of Set 9 | naze
# Processing Record 104 of Set 9 | vao
# Processing Record 105 of Set 9 | lata
# Processing Record 106 of Set 9 | sinnamary
# Processing Record 107 of Set 9 | svetlaya
# Processing Record 108 of Set 9 | terrace bay
# Processing Record 109 of Set 9 | jacareacanga
# Processing Record 110 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 111 of Set 10 | chitral
# Processing Record 112 of Set 10 | katherine
# Processing Record 113 of Set 10 | sao filipe
# Processing Record 114 of Set 10 | inhambane
# Processing Record 115 of Set 10 | terbuny
# Processing Record 116 of Set 10 | clyde river
# Processing Record 117 of Set 10 | yar-sale
# Processing Record 118 of Set 10 | kenai
# Processing Record 119 of Set 10 | vila franca do campo
# Processing Record 120 of Set 10 | bengkulu
# Processing Record 121 of Set 10 | baoqing
# Processing Record 122 of Set 10 | acri
# Processing Record 123 of Set 10 | golden
# Processing Record 124 of Set 10 | dikson
# Processing Record 125 of Set 10 | bubaque
# Processing Record 126 of Set 10 | fortuna
# Processing Record 127 of Set 10 | quelimane
# Processing Record 128 of Set 10 | half moon bay
# Processing Record 129 of Set 10 | asau
# Processing Record 130 of Set 10 | barrow
# Processing Record 131 of Set 10 | qandala
# Processing Record 132 of Set 10 | raudeberg
# Processing Record 133 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 134 of Set 11 | blagoyevo
# Processing Record 135 of Set 11 | kushmurun
# Processing Record 136 of Set 11 | saskylakh
# Processing Record 137 of Set 11 | muli
# Processing Record 138 of Set 11 | upernavik
# Processing Record 139 of Set 11 | camacha
# Processing Record 140 of Set 11 | medina
# Processing Record 141 of Set 11 | longyearbyen
# Processing Record 142 of Set 11 | nanortalik
# Processing Record 143 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 144 of Set 12 | tygda
# Processing Record 145 of Set 12 | weiser
# Processing Record 146 of Set 12 | nabire
# Processing Record 147 of Set 12 | nelson bay
# Processing Record 148 of Set 12 | pontes e lacerda
# Processing Record 149 of Set 12 | leningradskiy
# Processing Record 150 of Set 12 | ambilobe
# Processing Record 151 of Set 12 | teya
# Processing Record 152 of Set 12 | port blair
# Processing Record 153 of Set 12 | thompson
# Processing Record 154 of Set 12 | berdigestyakh
# Processing Record 155 of Set 12 | lebu
# Processing Record 156 of Set 12 | poyarkovo
# Processing Record 157 of Set 12 | wegorzewo
# Processing Record 158 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 159 of Set 13 | coracao de jesus
# Processing Record 160 of Set 13 | esperance
# Processing Record 161 of Set 13 | alta floresta
# Processing Record 162 of Set 13 | lasa
# Processing Record 163 of Set 13 | huarmey
# Processing Record 164 of Set 13 | caravelas
# Processing Record 165 of Set 13 | tsumeb
# Processing Record 166 of Set 13 | inongo
# Processing Record 167 of Set 13 | saint anthony
# Processing Record 168 of Set 13 | port lincoln
# Processing Record 169 of Set 13 | ryotsu
# Processing Record 170 of Set 13 | makurdi
# Processing Record 171 of Set 13 | alofi
# Processing Record 172 of Set 13 | hakkari
# Processing Record 173 of Set 13 | geraldton
# Processing Record 174 of Set 13 | risor
# Processing Record 175 of Set 13 | suksun
# Processing Record 176 of Set 13 | mar del plata
# Processing Record 177 of Set 13 | neepawa
# Processing Record 178 of Set 13 | antakya
# Processing Record 179 of Set 13 | yulara
# Processing Record 180 of Set 13 | san isidro
# Processing Record 181 of Set 13 | beberibe
# Processing Record 182 of Set 13 | lompoc
# Processing Record 183 of Set 13 | gobabis
# Processing Record 184 of Set 13 | balkhash
# Processing Record 185 of Set 13 | laguna
# Processing Record 186 of Set 13 | antibes
# Processing Record 187 of Set 13 | buribay
# Processing Record 188 of Set 13 | sioux lookout
# Processing Record 189 of Set 13 | provideniya
# Processing Record 190 of Set 13 | khatanga
# Processing Record 191 of Set 13 | polyarnyy
# Processing Record 192 of Set 13 | anloga
# Processing Record 193 of Set 13 | ossora
# Processing Record 194 of Set 13 | cooma
# Processing Record 195 of Set 13 | kavieng
# Processing Record 196 of Set 13 | tuktoyaktuk
# Processing Record 197 of Set 13 | lugovskoy
# Processing Record 198 of Set 13 | kavaratti
# Processing Record 199 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 200 of Set 14 | ketchikan
# Processing Record 201 of Set 14 | atar
# Processing Record 202 of Set 14 | iroquois falls
# Processing Record 203 of Set 14 | alyangula
# Processing Record 204 of Set 14 | altay
# Processing Record 205 of Set 14 | muroto
# Processing Record 206 of Set 14 | isangel
# Processing Record 207 of Set 14 | diamantino
# Processing Record 208 of Set 14 | jamestown
# Processing Record 209 of Set 14 | nikolskoye
# Processing Record 210 of Set 14 | dingle
# Processing Record 211 of Set 14 | avarua
# Processing Record 212 of Set 14 | wolomin
# Processing Record 213 of Set 14 | namibe
# Processing Record 214 of Set 14 | anchorage
# Processing Record 215 of Set 14 | ribeira grande
# Processing Record 216 of Set 14 | tangjiazhuang
# Processing Record 217 of Set 14 | san patricio
# Processing Record 218 of Set 14 | coahuayana
# Processing Record 219 of Set 14 | north bend
# Processing Record 220 of Set 14 | olavarria
# Processing Record 221 of Set 14 | ahipara
# Processing Record 222 of Set 14 | cherskiy
# Processing Record 223 of Set 14 | eyl
# Processing Record 224 of Set 14 | vitim
# Processing Record 225 of Set 14 | severo-kurilsk
# Processing Record 226 of Set 14 | airai
# Processing Record 227 of Set 14 | tautira
# Processing Record 228 of Set 14 | kovdor
# Processing Record 229 of Set 14 | holland
# Processing Record 230 of Set 14 | nadym
# Processing Record 231 of Set 14 | lisakovsk
# Processing Record 232 of Set 14 | pochutla
# Processing Record 233 of Set 14 | zhuhai
# Processing Record 234 of Set 14 | worthing
# Processing Record 235 of Set 14 | tezu
# Processing Record 236 of Set 14 | barra do garcas
# Processing Record 237 of Set 14 | nouadhibou
# Processing Record 238 of Set 14 | ndjole
# Processing Record 239 of Set 14 | iberia
# Processing Record 240 of Set 14 | avallon
# Processing Record 241 of Set 14 | paamiut
# Processing Record 242 of Set 14 | ixtapa
# Processing Record 243 of Set 14 | varkaus
# Processing Record 244 of Set 14 | vicuna
# Processing Record 245 of Set 14 | rio grande
# Processing Record 246 of Set 14 | baykit
# Processing Record 247 of Set 14 | tabou
# Processing Record 248 of Set 14 | moses lake
# Processing Record 249 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 250 of Set 15 | vanimo
# Processing Record 251 of Set 15 | fernley
# Processing Record 252 of Set 15 | tuburan
# Processing Record 253 of Set 15 | waipawa
# Processing Record 254 of Set 15 | redmond
# Processing Record 255 of Set 15 | east london
# Processing Record 256 of Set 15 | port elizabeth
# Processing Record 257 of Set 15 | san policarpo
# Processing Record 258 of Set 15 | castel goffredo
# Processing Record 259 of Set 15 | uray
# Processing Record 260 of Set 15 | mugango
# Processing Record 261 of Set 15 | pakdasht
# Processing Record 262 of Set 15 | mahebourg
# Processing Record 263 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 264 of Set 15 | saint george
# Processing Record 265 of Set 15 | chifeng
# Processing Record 266 of Set 15 | richards bay
# Processing Record 267 of Set 15 | marsh harbour
# Processing Record 268 of Set 15 | saint-prosper
# Processing Record 269 of Set 15 | faya
# Processing Record 270 of Set 15 | hamilton
# Processing Record 271 of Set 15 | aklavik
# Processing Record 272 of Set 15 | mujiayingzi
# Processing Record 273 of Set 15 | valpacos
# Processing Record 274 of Set 15 | cidreira
# Processing Record 275 of Set 15 | muisne
# Processing Record 276 of Set 15 | champagnole
# Processing Record 277 of Set 15 | cabo san lucas
# Processing Record 278 of Set 15 | kapit
# Processing Record 279 of Set 15 | zurrieq
# Processing Record 280 of Set 15 | gusau
# Processing Record 281 of Set 15 | kloulklubed
# Processing Record 282 of Set 15 | shache
# Processing Record 283 of Set 15 | chapais
# Processing Record 284 of Set 15 | iquique
# Processing Record 285 of Set 15 | oranjemund
# Processing Record 286 of Set 15 | grand gaube
# Processing Record 287 of Set 15 | yorosso
# Processing Record 288 of Set 15 | lavrentiya
# Processing Record 289 of Set 15 | praia da vitoria
# Processing Record 290 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 291 of Set 16 | ponta do sol
# Processing Record 292 of Set 16 | vila velha
# Processing Record 293 of Set 16 | manakara
# Processing Record 294 of Set 16 | kupang
# Processing Record 295 of Set 16 | tecoanapa
# Processing Record 296 of Set 16 | talara
# Processing Record 297 of Set 16 | teguldet
# Processing Record 298 of Set 16 | awbari
# Processing Record 299 of Set 16 | kadoma
# Processing Record 300 of Set 16 | victoria
# Processing Record 301 of Set 16 | sola
# Processing Record 302 of Set 16 | kars
# Processing Record 303 of Set 16 | sur
# Processing Record 304 of Set 16 | pozo colorado
# Processing Record 305 of Set 16 | vardo
# Processing Record 306 of Set 16 | chumikan
# Processing Record 307 of Set 16 | miranorte
# City not found. Skipping...
# Processing Record 308 of Set 17 | bijar
# Processing Record 309 of Set 17 | havoysund
# Processing Record 310 of Set 17 | manggar
# Processing Record 311 of Set 17 | henties bay
# Processing Record 312 of Set 17 | tafresh
# Processing Record 313 of Set 17 | palu
# Processing Record 314 of Set 17 | kruisfontein
# Processing Record 315 of Set 17 | katsuura
# Processing Record 316 of Set 17 | broome
# Processing Record 317 of Set 17 | taiyuan
# Processing Record 318 of Set 17 | maningrida
# Processing Record 319 of Set 17 | karwar
# Processing Record 320 of Set 17 | dolbeau
# City not found. Skipping...
# Processing Record 321 of Set 18 | renqiu
# Processing Record 322 of Set 18 | nishihara
# Processing Record 323 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 324 of Set 19 | sorland
# Processing Record 325 of Set 19 | haapiti
# Processing Record 326 of Set 19 | karamay
# City not found. Skipping...
# Processing Record 327 of Set 20 | vestmannaeyjar
# Processing Record 328 of Set 20 | kayerkan
# Processing Record 329 of Set 20 | bhimunipatnam
# Processing Record 330 of Set 20 | keuruu
# Processing Record 331 of Set 20 | boa vista
# Processing Record 332 of Set 20 | bage
# Processing Record 333 of Set 20 | ilulissat
# Processing Record 334 of Set 20 | lazaro cardenas
# Processing Record 335 of Set 20 | letterkenny
# Processing Record 336 of Set 20 | codrington
# Processing Record 337 of Set 20 | ailigandi
# Processing Record 338 of Set 20 | whitehorse
# Processing Record 339 of Set 20 | elizabeth city
# Processing Record 340 of Set 20 | pevek
# Processing Record 341 of Set 20 | marovoay
# Processing Record 342 of Set 20 | moerai
# Processing Record 343 of Set 20 | maragogi
# Processing Record 344 of Set 20 | newtownards
# Processing Record 345 of Set 20 | dori
# Processing Record 346 of Set 20 | antofagasta
# Processing Record 347 of Set 20 | kieta
# Processing Record 348 of Set 20 | parana
# Processing Record 349 of Set 20 | texarkana
# Processing Record 350 of Set 20 | sfantu gheorghe
# Processing Record 351 of Set 20 | qaqortoq
# Processing Record 352 of Set 20 | acari
# Processing Record 353 of Set 20 | marfino
# Processing Record 354 of Set 20 | mlonggo
# Processing Record 355 of Set 20 | hambantota
# Processing Record 356 of Set 20 | garm
# City not found. Skipping...
# Processing Record 357 of Set 21 | grindavik
# Processing Record 358 of Set 21 | dumka
# Processing Record 359 of Set 21 | tabiauea
# City not found. Skipping...
# Processing Record 360 of Set 22 | port hardy
# Processing Record 361 of Set 22 | ponta delgada
# Processing Record 362 of Set 22 | yarim
# Processing Record 363 of Set 22 | bargal
# City not found. Skipping...
# Processing Record 364 of Set 23 | marathon
# Processing Record 365 of Set 23 | tiarei
# Processing Record 366 of Set 23 | vestmanna
# Processing Record 367 of Set 23 | gunnedah
# Processing Record 368 of Set 23 | kysyl-syr
# Processing Record 369 of Set 23 | meulaboh
# Processing Record 370 of Set 23 | yuncheng
# Processing Record 371 of Set 23 | saint-joseph
# Processing Record 372 of Set 23 | orlik
# Processing Record 373 of Set 23 | pinhao
# Processing Record 374 of Set 23 | la ronge
# Processing Record 375 of Set 23 | beringovskiy
# Processing Record 376 of Set 23 | maarianhamina
# Processing Record 377 of Set 23 | avera
# Processing Record 378 of Set 23 | menongue
# Processing Record 379 of Set 23 | altamira
# Processing Record 380 of Set 23 | leshukonskoye
# Processing Record 381 of Set 23 | te anau
# Processing Record 382 of Set 23 | hualmay
# Processing Record 383 of Set 23 | pizarro
# Processing Record 384 of Set 23 | bandarbeyla
# Processing Record 385 of Set 23 | lamu
# Processing Record 386 of Set 23 | kostino
# Processing Record 387 of Set 23 | mackenzie
# Processing Record 388 of Set 23 | nizhneyansk
# City not found. Skipping...
# Processing Record 389 of Set 24 | pasni
# Processing Record 390 of Set 24 | kuala terengganu
# Processing Record 391 of Set 24 | nunchia
# Processing Record 392 of Set 24 | olinda
# Processing Record 393 of Set 24 | umarkot
# Processing Record 394 of Set 24 | guantanamo
# Processing Record 395 of Set 24 | ternate
# Processing Record 396 of Set 24 | yumen
# Processing Record 397 of Set 24 | eureka
# Processing Record 398 of Set 24 | tiksi
# Processing Record 399 of Set 24 | merauke
# Processing Record 400 of Set 24 | andros town
# Processing Record 401 of Set 24 | suraabad
# Processing Record 402 of Set 24 | ancud
# Processing Record 403 of Set 24 | tawang
# Processing Record 404 of Set 24 | hachinohe
# Processing Record 405 of Set 24 | udarnyy
# Processing Record 406 of Set 24 | topchanchi
# Processing Record 407 of Set 24 | blind river
# Processing Record 408 of Set 24 | gympie
# Processing Record 409 of Set 24 | tumbi
# Processing Record 410 of Set 24 | hami
# Processing Record 411 of Set 24 | kokopo
# Processing Record 412 of Set 24 | adrar
# Processing Record 413 of Set 24 | san quintin
# Processing Record 414 of Set 24 | visnes
# Processing Record 415 of Set 24 | hovd
# Processing Record 416 of Set 24 | djougou
# Processing Record 417 of Set 24 | mandali
# Processing Record 418 of Set 24 | petatlan
# Processing Record 419 of Set 24 | villa guerrero
# Processing Record 420 of Set 24 | sibu
# Processing Record 421 of Set 24 | port macquarie
# Processing Record 422 of Set 24 | aksu
# Processing Record 423 of Set 24 | karlstad
# Processing Record 424 of Set 24 | balakirevo
# Processing Record 425 of Set 24 | ndele
# Processing Record 426 of Set 24 | poum
# Processing Record 427 of Set 24 | farafangana
# Processing Record 428 of Set 24 | bismarck
# Processing Record 429 of Set 24 | quesnel
# Processing Record 430 of Set 24 | staraya poltavka
# Processing Record 431 of Set 24 | banda aceh
# Processing Record 432 of Set 24 | beloha
# Processing Record 433 of Set 24 | verkhnyaya inta
# Processing Record 434 of Set 24 | pimentel
# Processing Record 435 of Set 24 | coos bay
# Processing Record 436 of Set 24 | marcona
# City not found. Skipping...
# Processing Record 437 of Set 25 | dalnerechensk
# Processing Record 438 of Set 25 | bayan
# Processing Record 439 of Set 25 | constantine
# Processing Record 440 of Set 25 | tual
# Processing Record 441 of Set 25 | bilma
# Processing Record 442 of Set 25 | tabas
# Processing Record 443 of Set 25 | el dorado
# Processing Record 444 of Set 25 | merke
# Processing Record 445 of Set 25 | lorengau
# Processing Record 446 of Set 25 | novoorsk
# Processing Record 447 of Set 25 | kasama
# Processing Record 448 of Set 25 | college
# Processing Record 449 of Set 25 | muzquiz
# City not found. Skipping...
# Processing Record 450 of Set 26 | aflu
# City not found. Skipping...
# Processing Record 451 of Set 27 | huangzhou
# Processing Record 452 of Set 27 | ambon
# Processing Record 453 of Set 27 | srednekolymsk
# Processing Record 454 of Set 27 | bambous virieux
# Processing Record 455 of Set 27 | benicarlo
# Processing Record 456 of Set 27 | talnakh
# Processing Record 457 of Set 27 | uusikaupunki
# Processing Record 458 of Set 27 | narsaq
# Processing Record 459 of Set 27 | riberalta
# Processing Record 460 of Set 27 | harper
# Processing Record 461 of Set 27 | coquimbo
# Processing Record 462 of Set 27 | meyungs
# City not found. Skipping...
# Processing Record 463 of Set 28 | vangaindrano
# Processing Record 464 of Set 28 | palabuhanratu
# City not found. Skipping...
# Processing Record 465 of Set 29 | malakal
# Processing Record 466 of Set 29 | mayna
# Processing Record 467 of Set 29 | novhorodka
# Processing Record 468 of Set 29 | tucuman
# Processing Record 469 of Set 29 | attawapiskat
# City not found. Skipping...
# Processing Record 470 of Set 30 | ngaoundere
# Processing Record 471 of Set 30 | bereda
# Processing Record 472 of Set 30 | ginir
# Processing Record 473 of Set 30 | charlestown
# Processing Record 474 of Set 30 | soeng sang
# Processing Record 475 of Set 30 | imbituba
# Processing Record 476 of Set 30 | gedo
# Processing Record 477 of Set 30 | puerto escondido
# Processing Record 478 of Set 30 | marrakesh
# Processing Record 479 of Set 30 | mentok
# City not found. Skipping...
# Processing Record 480 of Set 31 | manhush
# Processing Record 481 of Set 31 | constitucion
# Processing Record 482 of Set 31 | araouane
# Processing Record 483 of Set 31 | komsomolskiy
# Processing Record 484 of Set 31 | honiara
# Processing Record 485 of Set 31 | asfi
# Processing Record 486 of Set 31 | toamasina
# Processing Record 487 of Set 31 | sarangani
# Processing Record 488 of Set 31 | mantua
# Processing Record 489 of Set 31 | yamada
# Processing Record 490 of Set 31 | juneau
# Processing Record 491 of Set 31 | sungaipenuh
# Processing Record 492 of Set 31 | ler
# Processing Record 493 of Set 31 | lexington
# Processing Record 494 of Set 31 | naryan-mar
# Processing Record 495 of Set 31 | barbar
# City not found. Skipping...
# Processing Record 496 of Set 32 | yerbogachen
# Processing Record 497 of Set 32 | peterhead
# Processing Record 498 of Set 32 | saint-francois
# Processing Record 499 of Set 32 | chicama
# Processing Record 500 of Set 32 | fare
# Processing Record 501 of Set 32 | yelanskiy
# Processing Record 502 of Set 32 | panama city
# Processing Record 503 of Set 32 | floro
# Processing Record 504 of Set 32 | linchuan
# City not found. Skipping...
# Processing Record 505 of Set 33 | samarkand
# Processing Record 506 of Set 33 | sabibah
# City not found. Skipping...
# Processing Record 507 of Set 34 | soto la marina
# Processing Record 508 of Set 34 | umzimvubu
# City not found. Skipping...
# Processing Record 509 of Set 35 | gondanglegi
# Processing Record 510 of Set 35 | utiroa
# City not found. Skipping...
# Processing Record 511 of Set 36 | aksarka
# Processing Record 512 of Set 36 | ladario
# Processing Record 513 of Set 36 | terney
# Processing Record 514 of Set 36 | port-cartier
# Processing Record 515 of Set 36 | varna
# Processing Record 516 of Set 36 | ondorhaan
# City not found. Skipping...
# Processing Record 517 of Set 37 | kanigiri
# Processing Record 518 of Set 37 | bengbu
# Processing Record 519 of Set 37 | sheltozero
# Processing Record 520 of Set 37 | mancio lima
# Processing Record 521 of Set 37 | ous
# Processing Record 522 of Set 37 | okato
# Processing Record 523 of Set 37 | dire dawa
# Processing Record 524 of Set 37 | turiacu
# Processing Record 525 of Set 37 | faanui
# Processing Record 526 of Set 37 | abu dhabi
# Processing Record 527 of Set 37 | san blas
# Processing Record 528 of Set 37 | bombay
# Processing Record 529 of Set 37 | vetapalem
# Processing Record 530 of Set 37 | huangchuan
# Processing Record 531 of Set 37 | bahia honda
# Processing Record 532 of Set 37 | nome
# Processing Record 533 of Set 37 | shakawe
# Processing Record 534 of Set 37 | cap-aux-meules
# Processing Record 535 of Set 37 | berlevag
# Processing Record 536 of Set 37 | dunedin
# Processing Record 537 of Set 37 | vila do maio
# Processing Record 538 of Set 37 | tochimilco
# Processing Record 539 of Set 37 | fernandez
# Processing Record 540 of Set 37 | baboua
# City not found. Skipping...
# Processing Record 541 of Set 38 | el badari
# City not found. Skipping...
# Processing Record 542 of Set 39 | mecca
# Processing Record 543 of Set 39 | cap malheureux
# Processing Record 544 of Set 39 | thinadhoo
# Processing Record 545 of Set 39 | sharjah
# Processing Record 546 of Set 39 | abu kamal
# Processing Record 547 of Set 39 | nuuk
# Processing Record 548 of Set 39 | helong
# Processing Record 549 of Set 39 | santa catalina
# Processing Record 550 of Set 39 | ligayan
# Processing Record 551 of Set 39 | haines junction
# Processing Record 552 of Set 39 | rungata
# City not found. Skipping...
# Processing Record 553 of Set 40 | peleduy
# Processing Record 554 of Set 40 | prince rupert
# Processing Record 555 of Set 40 | chestermere
# Processing Record 556 of Set 40 | villa carlos paz
# Processing Record 557 of Set 40 | ashland
# Processing Record 558 of Set 40 | rognedino
# Processing Record 559 of Set 40 | pitimbu
# Processing Record 560 of Set 40 | chupaca
# Processing Record 561 of Set 40 | brookings
# Processing Record 562 of Set 40 | sitka
# Processing Record 563 of Set 40 | lodja
# Processing Record 564 of Set 40 | san andres
# Processing Record 565 of Set 40 | aswan
# Processing Record 566 of Set 40 | kichera
# Processing Record 567 of Set 40 | outjo
# Processing Record 568 of Set 40 | mendahara
# City not found. Skipping...
# Processing Record 569 of Set 41 | naruto
# Processing Record 570 of Set 41 | xichang
# Processing Record 571 of Set 41 | clinton
# Processing Record 572 of Set 41 | pietroasa
# Processing Record 573 of Set 41 | bolungarvik
# City not found. Skipping...
# Processing Record 574 of Set 42 | samalaeulu
# City not found. Skipping...
# Processing Record 575 of Set 43 | mayskiy
# Processing Record 576 of Set 43 | guerrero negro
# Processing Record 577 of Set 43 | quatre cocos
# Processing Record 578 of Set 43 | mayo
# Processing Record 579 of Set 43 | phan rang
# City not found. Skipping...
# Processing Record 580 of Set 44 | kawalu
# Processing Record 581 of Set 44 | kaitangata
# Processing Record 582 of Set 44 | saint-augustin
# Processing Record 583 of Set 44 | dalby
# Processing Record 584 of Set 44 | kholodnyy
# Processing Record 585 of Set 44 | popova
# Processing Record 586 of Set 44 | ruatoria
# City not found. Skipping...
# Processing Record 587 of Set 45 | athens
# Processing Record 588 of Set 45 | leh
# Processing Record 589 of Set 45 | dawson creek
# Processing Record 590 of Set 45 | windhoek
# Processing Record 591 of Set 45 | turkmenabat
# Processing Record 592 of Set 45 | gornoye loo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Build dictionary of lists with clean column headers
weather_dict={
    'City':fndcity,'Lat':lat, 'Lng':lng,
    'Max Temp':mxtemp,'Humidity':humd,'Cloudiness':cloud,
    'Wind Speed':wndsp, 'Country':cntry, 'Date':date
}

# Convert dictionary of lists to dataframe object
weather_df = pd.DataFrame(weather_dict)

# Save dataframe as a csv value with stripped index for easier intake in future projects
weather_df.to_csv(output_data_file,index=False)

weather_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Solnechnyy  50.7214  136.6319      3.06        90          73
# 1         Bethel  41.3712  -73.4140     19.99        49           1
# 2         Xining  36.6167  101.7667     30.78        78         100
# 3         Albany  42.6001  -73.9662     14.00        51           0
# 4  Krasnosel'kup  65.7000   82.4667    -40.52        75           0
#
#    Wind Speed Country        Date
# 0        2.82      RU  1611467381
# 1        6.91      US  1611467381
# 2        5.99      CN  1611467381
# 3       11.99      US  1611467381
# 4        4.81      RU  1611467381

# %%
# Check those stats
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  549.000000  549.000000  549.000000  549.000000  549.000000  549.000000
# mean    19.919239   18.668395   49.647049   73.593807   56.078324    7.869362
# std     33.421870   91.706029   33.211597   19.573575   38.337762    5.875846
# min    -54.800000 -175.200000  -49.340000    9.000000    0.000000    0.200000
# 25%     -8.767600  -61.859700   30.200000   66.000000   19.000000    3.440000
# 50%     24.266700   24.700000   59.590000   78.000000   72.000000    6.640000
# 75%     47.666600  100.335400   75.720000   88.000000   91.000000   10.780000
# max     78.218600  179.316700  106.750000  100.000000  100.000000   32.210000
#
#                Date
# count  5.490000e+02
# mean   1.611467e+09
# std    7.820584e+01
# min    1.611467e+09
# 25%    1.611467e+09
# 50%    1.611467e+09
# 75%    1.611467e+09
# max    1.611467e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Find all rows with humidity erroneously showing up greater than 100%
hum_count = weather_df[weather_df['Humidity']>100].count()
hum_count
# Out:
# City          0
# Lat           0
# Lng           0
# Max Temp      0
# Humidity      0
# Cloudiness    0
# Wind Speed    0
# Country       0
# Date          0
# dtype: int64

# %%
#  Get the indices of cities that have humidity over 100%.
hum_index = weather_df[weather_df['Humidity']>100].index
hum_index
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = weather_df.drop(hum_index, inplace=False)

# %%
# Check those stats
clean_city_data.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  549.000000  549.000000  549.000000  549.000000  549.000000  549.000000
# mean    19.919239   18.668395   49.647049   73.593807   56.078324    7.869362
# std     33.421870   91.706029   33.211597   19.573575   38.337762    5.875846
# min    -54.800000 -175.200000  -49.340000    9.000000    0.000000    0.200000
# 25%     -8.767600  -61.859700   30.200000   66.000000   19.000000    3.440000
# 50%     24.266700   24.700000   59.590000   78.000000   72.000000    6.640000
# 75%     47.666600  100.335400   75.720000   88.000000   91.000000   10.780000
# max     78.218600  179.316700  106.750000  100.000000  100.000000   32.210000
#
#                Date
# count  5.490000e+02
# mean   1.611467e+09
# std    7.820584e+01
# min    1.611467e+09
# 25%    1.611467e+09
# 50%    1.611467e+09
# 75%    1.611467e+09
# max    1.611467e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Using pandas plot temperature vs. latitude, save as png in output_data folder
clean_city_data.plot.scatter('Lat',"Max Temp", c='Max Temp',title='Max Temp vs Latitude',
                             colormap='coolwarm',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Max Temp (F)',fontsize=12)
plt.savefig('output_data/lat_temp.png')

# %% [markdown]
# >Warmer temperatures at negative latitudes indicate that it is currently summer in the sourthern hemisphere.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Using pandas plot humidity vs latitude, save as png in output_data folder
clean_city_data.plot.scatter('Lat',"Humidity", c='Humidity',title='Humidity vs Latitude',
                             colormap='BrBG',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Humidity (%)',fontsize=12)
plt.savefig('output_data/lat_humd.png')

# %% [markdown]
# >Overall Earth is a relatively moist planet, with a few dry spots shouldering the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Using pandas plot cloudiness vs. latitude, save as png in output_data folder
clean_city_data.plot.scatter('Lat',"Cloudiness", c='Cloudiness',title='Cloudiness vs Latitude',
                             colormap='bone',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Cloudiness (%)',fontsize=12)
plt.savefig('output_data/lat_cloud.png')

# %% [markdown]
# >Cloudiness appears to be relatively evenly distributed versus latitude. Perhaps just slightly cloudier in the Northern Hemisphere currently during winter.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Using pandas plot wind speed vs. latitude, save as png in output_data folder
clean_city_data.plot.scatter('Lat',"Wind Speed", c='Wind Speed',title='Wind Speed vs Latitude',
                             colormap='Reds',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Wind Speed  (mph)',fontsize=12)
plt.savefig('output_data/lat_wind.png')

# %% [markdown]
# >Very slight increase in windspeed in the Northern Hemisphere during the winter months.

# %% [markdown]
# ## Linear Regression

# %%
# Prepare dataframes for northern and southern hemispheres
north_df = clean_city_data[clean_city_data['Lat']>0]
south_df = clean_city_data[clean_city_data['Lat']<0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Using pandas plot max temperature vs latitude for the northern hemisphere
north_df.plot.scatter('Lat',"Max Temp", c='Max Temp',title='Northern Hem-Max Temp vs Latitude',
                             colormap='coolwarm',marker='D',figsize=(8,5), fontsize=12,colorbar=False)
# Set plot labels
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Max Temp (F)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'], north_df['Max Temp'])

# Calculate target values for regression line 
regress_values = north_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line over scatter data
plt.plot(north_df['Lat'],regress_values,'-r')

# Print regression equation to plot
plt.text(2,-10,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

# Save the figure for later use
plt.savefig('output_data/reg_norlat_temp.png')

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Using pandas plot max temperature vs latitude for the southern hemisphere
south_df.plot.scatter('Lat',"Max Temp", c='Max Temp',title='Southern Hem-Max Temp vs Latitude',
                             colormap='coolwarm',marker='D',figsize=(8,5), fontsize=12,colorbar=False)
# Set plot labels
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Max Temp (F)',fontsize=12)
# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'], south_df['Max Temp'])

# Calculate target values for regression line 
regress_values = south_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line over scatter data
plt.plot(south_df['Lat'],regress_values,"r-")

# Print regression equation to plot
plt.text(-35,55,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

# Save plot for future use
plt.savefig('output_data/reg_sudlat_temp.png')

# %% [markdown]
# >Regression analysis of temperature vs latitude by northern/southern hemisphere indicate that the further away from the equator the cooler the temperature. Temperatures while traveling north get colder quicker due to seasonal influence.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Using pandas plot max humidity vs latitude for the northern hemisphere
north_df.plot.scatter('Lat',"Humidity", c='Humidity',title='Northern Hem-Humidity vs Latitude',
                             colormap='BrBG',marker='D',figsize=(8,5), fontsize=12,colorbar=False)
# Set plot labels
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Humidity (%)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'], north_df['Humidity'])

# Calculate target values for regression line 
regress_values = north_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line on scatter data
plt.plot(north_df['Lat'],regress_values,'-r')

# Print regression equation to plot
plt.text(45,25,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

# Save plot for future use
plt.savefig('output_data/reg_norlat_humd.png')

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Using pandas plot humidity vs latitude for the southern hemisphere
south_df.plot.scatter('Lat',"Humidity", c='Humidity',title='Southern Hem-Humidity vs Latitude',
                             colormap='BrBG',marker='D',figsize=(8,5), fontsize=12,colorbar=False)

# Set plot labels
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Humidity (%)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'], south_df['Humidity'])

# Calculate target values for regression line 
regress_values = south_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line over scatter data
plt.plot(south_df['Lat'],regress_values,"r-")

# Print regression equation to plot
plt.text(-20,11,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

# Save plot for future use
plt.savefig('output_data/reg_sudlat_humd.png')

# %% [markdown]
# >Definitive bands of 'dryness' appear in both hemispheres. While the nothern hemisphere gains moisture content at increasing latitude, the southern hemisphere becomes more arid as you progress away from the equator.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Using pandas plot max cloudiness vs latitude for the northern hemisphere
north_df.plot.scatter('Lat',"Cloudiness", c='Cloudiness',title='Northern Hem-Cloudiness vs Latitude',
                             colormap='bone',marker='D',figsize=(8,5), fontsize=12,colorbar=False)
# Set plot labels
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Cloudiness (%)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'], north_df['Cloudiness'])

# Calculate target values for regression line 
regress_values = north_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line over scatter data
plt.plot(north_df['Lat'],regress_values,'-r')

# Print regression equation to plot
plt.text(40,95,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

# Save figure for future use
plt.savefig('output_data/reg_norlat_cloud.png')

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Using pandas plot cloudiness vs latitude for the southern hemisphere
south_df.plot.scatter('Lat',"Cloudiness", c='Cloudiness',title='Southern Hem-Cloudiness vs Latitude',
                             colormap='bone',marker='D',figsize=(8,5), fontsize=12,colorbar=False)
# Set plot labels
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Cloudiness (%)',fontsize=12)
# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'], south_df['Cloudiness'])

# Calculate target values for regression line 
regress_values = south_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line over scatter data
plt.plot(south_df['Lat'],regress_values,"r-")

# Print regression equation on plot
plt.text(-55,95,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

# Save plot for future use
plt.savefig('output_data/reg_sudlat_cloud.png')

# %% [markdown]
# >While the data shows fairly even distribution overall, cloud cover increase from south pole to north pole. Perhaps as an effect of seasonal influence or perhaps more data is needed in the southern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Using pandas plot wind speed vs latitude for the northern hemisphere
north_df.plot.scatter('Lat',"Wind Speed", c='Wind Speed',title='Northern Hem-Wind Speed vs Latitude',
                             colormap='Reds',marker='D',figsize=(8,5), fontsize=12,colorbar=False)
# Set plot labels
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Wind Speed (mph)',fontsize=12)

# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(north_df['Lat'], north_df['Wind Speed'])

# Calculate target values for regression line 
regress_values = north_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line over scatter data
plt.plot(north_df['Lat'],regress_values,'-r')

# Print regression equation on plot
plt.text(0,25,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

# Save plot for future use
plt.savefig('output_data/reg_norlat_wind.png')

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Using pandas plot wind speed vs latitude for the souther hemisphere
south_df.plot.scatter('Lat',"Wind Speed", c='Wind Speed',title='Southern Hem-Wind Speed vs Latitude',
                             colormap='Reds',marker='D',figsize=(8,5), fontsize=12,colorbar=False)
# Set plot labels
plt.xlabel('Latitude',fontsize=12)
plt.ylabel('Wind Speed (mph)',fontsize=12)
# Assign lingress output to each output parameter as a variable
(slope, intercept, rvalue, pvalue, stderr) = linregress(south_df['Lat'], south_df['Wind Speed'])

# Calculate target values for regression line 
regress_values = south_df['Lat'] * slope + intercept

# Assign regression equation to string object to print onto plot
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Plot regression line over scatter data
plt.plot(south_df['Lat'],regress_values,"r-")

# Print regression equation on plot
plt.text(-20,30,line_eq,fontsize=16,color="darkblue",style='oblique',
       bbox={'facecolor': 'red', 'alpha': 0.5, 'pad': 10})

# Save plot for future use
plt.savefig('output_data/reg_sudlat_wind.png')

# %% [markdown]
# >Windspeed very evenly distributed in the northern hemisphere with little to no change latitudinally. Wind speeds in the southern hemisphere increase mildly from equator to south pole.
